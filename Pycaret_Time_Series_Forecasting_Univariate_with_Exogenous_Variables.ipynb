# %% [markdown]
# <a href="https://colab.research.google.com/github/ParsaKeerthana/DataMiningAssignment/blob/main/Pycaret_Time_Series_Forecasting_Univariate_with_Exogenous_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret

# %%
import pandas as pd

sales_data = pd.read_csv("/content/synthetic_sales_data.csv")
sales_data.head()
# Out:
#          Date       Sales  Holiday  Promotion
# 0  2020-01-01  204.967142        0          0
# 1  2020-01-02  250.338438       50          0
# 2  2020-01-03  239.917007        0         30
# 3  2020-01-04  270.385383       50          0
# 4  2020-01-05  204.522405        0          0

# %%
from pycaret.time_series import setup, create_model, compare_models, predict_model
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error

# %%
# PyCaret setup
s = setup(data=sales_data['Sales'], fh=12, fold=3, seasonal_period=7)
# Out:
# <style type="text/css">
# #T_7be27_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7be27" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7be27_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7be27_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7be27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7be27_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_7be27_row0_col1" class="data row0 col1" >8336</td>
#     </tr>
#     <tr>
#       <th id="T_7be27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7be27_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7be27_row1_col1" class="data row1 col1" >Sales</td>
#     </tr>
#     <tr>
#       <th id="T_7be27_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Compare models
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_31e14 th {
#   text-align: left;
# }
# ...
